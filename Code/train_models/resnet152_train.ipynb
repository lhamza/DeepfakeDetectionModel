# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os

# TODO: Fill in the Google Drive path where you uploaded the project folder
# Example: GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'Colab Notebooks/CW_Folder'

GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'DeepfakeDetectionModel'
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ['Dataset', 'Code', 'Models', 'resnet34_train.ipynb', 'resnet50_train.ipynb', 'resnet101_train.ipynb', 'resnet152_train.ipynb']

# %%
DATASET_FOLDER = os.path.join(GOOGLE_DRIVE_PATH, 'Dataset', 'Dataset_Cropped')
CODE_FOLDER = os.path.join(GOOGLE_DRIVE_PATH, 'Code')
print(os.listdir(DATASET_FOLDER))
print(os.listdir(CODE_FOLDER))
# Out:
# ['.DS_Store', 'train', 'test']
# ['resnet34.py', '__pycache__', 'calculate_mean_std.py', 'resnet50.py', 'resnet152.py', 'resnet101.py']

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append(CODE_FOLDER)

# %%
from resnet152 import ResNet152
from calculate_mean_std import calculate_mean_std

# %%
train_dataset_path = os.path.join(DATASET_FOLDER, 'train')

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:
print(device)
# Out:
# cuda:0

# %%
stats_transform = transforms.Compose([
    transforms.Resize((500, 500)),
    transforms.ToTensor(),
])

stats_dataset = torchvision.datasets.ImageFolder(root=train_dataset_path, transform=stats_transform)

stats_loader = DataLoader(stats_dataset, batch_size=4, shuffle=True, num_workers=2)

calc_mean, calc_std = calculate_mean_std(stats_loader)

print(f'Mean: {calc_mean}')
print(f'Std: {calc_std}')
# Out:
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Mean: tensor([0.5498, 0.4155, 0.3822])
# Std: tensor([0.2164, 0.1714, 0.1615])

# %%
transform = transforms.Compose([
    transforms.Resize((500, 500)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(30),
    transforms.ToTensor(),
    transforms.Normalize(mean=calc_mean, std=calc_std),
])

dataset = torchvision.datasets.ImageFolder(root=train_dataset_path, transform=transform)

train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=4, shuffle=False, num_workers=2)

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(train_dataset_path, validation_split=0.2, subset="training", seed=123)
# Out:
# Found 2948 files belonging to 3 classes.
# Using 2359 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(train_dataset_path, validation_split=0.2, subset="validation", seed=123)
# Out:
# Found 2948 files belonging to 3 classes.
# Using 589 files for validation.

# %%
model = ResNet152()

# %%
criterion = tf.keras.losses.SparseCategoricalCrossentropy()
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# %%
model.compile(optimizer=optimizer, loss=criterion, metrics=['accuracy'])

# %%
num_epochs = 100
history = model.fit(train_ds, epochs=num_epochs, validation_data=val_ds)
# Out:
# Epoch 1/100
# 74/74 [==============================] - 160s 695ms/step - loss: 13.9238 - accuracy: 0.3226 - val_loss: 630853.1875 - val_accuracy: 0.3413
# Epoch 2/100
# 74/74 [==============================] - 42s 563ms/step - loss: 2.5595 - accuracy: 0.3332 - val_loss: 1.8657 - val_accuracy: 0.3497
# Epoch 3/100
# 74/74 [==============================] - 42s 569ms/step - loss: 1.2745 - accuracy: 0.3531 - val_loss: 1.1008 - val_accuracy: 0.3871
# Epoch 4/100
# 74/74 [==============================] - 43s 573ms/step - loss: 1.2024 - accuracy: 0.3764 - val_loss: 1.1008 - val_accuracy: 0.3548
# Epoch 5/100
# 74/74 [==============================] - 43s 577ms/step - loss: 1.1475 - accuracy: 0.3807 - val_loss: 1.4611 - val_accuracy: 0.3582
# Epoch 6/100
# 74/74 [==============================] - 43s 574ms/step - loss: 1.0919 - accuracy: 0.4180 - val_loss: 1.2219 - val_accuracy: 0.3803
# Epoch 7/100
# 74/74 [==============================] - 43s 576ms/step - loss: 1.0481 - accuracy: 0.4426 - val_loss: 1.0925 - val_accuracy: 0.3718
# Epoch 8/100
# 74/74 [==============================] - 43s 575ms/step - loss: 1.0500 - accuracy: 0.4307 - val_loss: 1.0875 - val_accuracy: 0.3973
# Epoch 9/100
# 74/74 [==============================] - 43s 575ms/step - loss: 1.0380 - accuracy: 0.4426 - val_loss: 1.0586 - val_accuracy: 0.4194
# Epoch 10/100
# 74/74 [==============================] - 43s 574ms/step - loss: 1.0218 - accuracy: 0.4485 - val_loss: 1.0311 - val_accuracy: 0.4567
# Epoch 11/100
# 74/74 [==============================] - 43s 575ms/step - loss: 1.0340 - accuracy: 0.4464 - val_loss: 1.1774 - val_accuracy: 0.4177
# Epoch 12/100
# 74/74 [==============================] - 43s 575ms/step - loss: 1.0145 - accuracy: 0.4688 - val_loss: 1.0541 - val_accuracy: 0.4431
# Epoch 13/100
# 74/74 [==============================] - 43s 575ms/step - loss: 1.0011 - accuracy: 0.4671 - val_loss: 1.0216 - val_accuracy: 0.4363
# Epoch 14/100
# 74/74 [==============================] - 43s 575ms/step - loss: 1.0072 - accuracy: 0.4909 - val_loss: 1.0223 - val_accuracy: 0.4720
# Epoch 15/100
# 74/74 [==============================] - 43s 575ms/step - loss: 1.0609 - accuracy: 0.4688 - val_loss: 1.0243 - val_accuracy: 0.4482
# Epoch 16/100
# 74/74 [==============================] - 43s 575ms/step - loss: 1.0345 - accuracy: 0.4879 - val_loss: 1.0658 - val_accuracy: 0.4126
# Epoch 17/100
# 74/74 [==============================] - 43s 573ms/step - loss: 0.9879 - accuracy: 0.5015 - val_loss: 1.0292 - val_accuracy: 0.4397
# Epoch 18/100
# 74/74 [==============================] - 43s 573ms/step - loss: 0.9509 - accuracy: 0.5345 - val_loss: 1.0169 - val_accuracy: 0.4839
# Epoch 19/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.9248 - accuracy: 0.5553 - val_loss: 1.0305 - val_accuracy: 0.4686
# Epoch 20/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.9230 - accuracy: 0.5625 - val_loss: 1.0212 - val_accuracy: 0.4703
# Epoch 21/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.9041 - accuracy: 0.5646 - val_loss: 1.0415 - val_accuracy: 0.4652
# Epoch 22/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.8820 - accuracy: 0.5897 - val_loss: 1.0129 - val_accuracy: 0.4856
# Epoch 23/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.8790 - accuracy: 0.5748 - val_loss: 0.9661 - val_accuracy: 0.5144
# Epoch 24/100
# 74/74 [==============================] - 43s 574ms/step - loss: 0.8802 - accuracy: 0.5905 - val_loss: 0.9960 - val_accuracy: 0.4856
# Epoch 25/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.8517 - accuracy: 0.6041 - val_loss: 1.3705 - val_accuracy: 0.5365
# Epoch 26/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.8203 - accuracy: 0.6240 - val_loss: 1.0211 - val_accuracy: 0.5161
# Epoch 27/100
# 74/74 [==============================] - 43s 574ms/step - loss: 0.8177 - accuracy: 0.6164 - val_loss: 1.0233 - val_accuracy: 0.5008
# Epoch 28/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.9069 - accuracy: 0.5914 - val_loss: 11.7384 - val_accuracy: 0.3430
# Epoch 29/100
# 74/74 [==============================] - 43s 574ms/step - loss: 1.2059 - accuracy: 0.4451 - val_loss: 13909.4775 - val_accuracy: 0.3226
# Epoch 30/100
# 74/74 [==============================] - 43s 573ms/step - loss: 0.9924 - accuracy: 0.5269 - val_loss: 195.5519 - val_accuracy: 0.3531
# Epoch 31/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.8689 - accuracy: 0.5850 - val_loss: 1.0269 - val_accuracy: 0.4856
# Epoch 32/100
# 74/74 [==============================] - 43s 574ms/step - loss: 0.8128 - accuracy: 0.6253 - val_loss: 1.0605 - val_accuracy: 0.4618
# Epoch 33/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.8061 - accuracy: 0.6346 - val_loss: 1.0226 - val_accuracy: 0.4669
# Epoch 34/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.7677 - accuracy: 0.6507 - val_loss: 2.2501 - val_accuracy: 0.4550
# Epoch 35/100
# 74/74 [==============================] - 43s 574ms/step - loss: 0.7246 - accuracy: 0.6723 - val_loss: 1.0972 - val_accuracy: 0.5042
# Epoch 36/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.7076 - accuracy: 0.6901 - val_loss: 1.1895 - val_accuracy: 0.4686
# Epoch 37/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.6935 - accuracy: 0.6833 - val_loss: 1.0040 - val_accuracy: 0.5314
# Epoch 38/100
# 74/74 [==============================] - 43s 572ms/step - loss: 0.6273 - accuracy: 0.7351 - val_loss: 1.0246 - val_accuracy: 0.5433
# Epoch 39/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.6010 - accuracy: 0.7372 - val_loss: 1.0880 - val_accuracy: 0.5433
# Epoch 40/100
# 74/74 [==============================] - 43s 576ms/step - loss: 0.5714 - accuracy: 0.7558 - val_loss: 1.1742 - val_accuracy: 0.5076
# Epoch 41/100
# 74/74 [==============================] - 43s 572ms/step - loss: 0.5773 - accuracy: 0.7507 - val_loss: 1.1001 - val_accuracy: 0.5161
# Epoch 42/100
# 74/74 [==============================] - 43s 573ms/step - loss: 0.5574 - accuracy: 0.7652 - val_loss: 1.2627 - val_accuracy: 0.4941
# Epoch 43/100
# 74/74 [==============================] - 43s 574ms/step - loss: 0.5418 - accuracy: 0.7753 - val_loss: 10.8676 - val_accuracy: 0.3888
# Epoch 44/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.4653 - accuracy: 0.7936 - val_loss: 1.1338 - val_accuracy: 0.5144
# Epoch 45/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.4420 - accuracy: 0.8114 - val_loss: 4.1337 - val_accuracy: 0.4941
# Epoch 46/100
# 74/74 [==============================] - 43s 572ms/step - loss: 0.4330 - accuracy: 0.8228 - val_loss: 1.6859 - val_accuracy: 0.5297
# Epoch 47/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.4240 - accuracy: 0.8207 - val_loss: 1.4552 - val_accuracy: 0.4958
# Epoch 48/100
# 74/74 [==============================] - 43s 574ms/step - loss: 0.4178 - accuracy: 0.8326 - val_loss: 1.6431 - val_accuracy: 0.5110
# Epoch 49/100
# 74/74 [==============================] - 43s 574ms/step - loss: 0.3773 - accuracy: 0.8504 - val_loss: 1.3757 - val_accuracy: 0.5348
# Epoch 50/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.3448 - accuracy: 0.8563 - val_loss: 1.3421 - val_accuracy: 0.5348
# Epoch 51/100
# 74/74 [==============================] - 43s 574ms/step - loss: 0.3774 - accuracy: 0.8538 - val_loss: 1.4969 - val_accuracy: 0.5263
# Epoch 52/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.3142 - accuracy: 0.8682 - val_loss: 1.2779 - val_accuracy: 0.5586
# Epoch 53/100
# 74/74 [==============================] - 43s 574ms/step - loss: 0.3306 - accuracy: 0.8618 - val_loss: 1.2057 - val_accuracy: 0.5331
# Epoch 54/100
# 74/74 [==============================] - 43s 573ms/step - loss: 0.3300 - accuracy: 0.8728 - val_loss: 1.4327 - val_accuracy: 0.5433
# Epoch 55/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.3067 - accuracy: 0.8766 - val_loss: 7.4105 - val_accuracy: 0.5246
# Epoch 56/100
# 74/74 [==============================] - 43s 574ms/step - loss: 0.2647 - accuracy: 0.8953 - val_loss: 2.1400 - val_accuracy: 0.5552
# Epoch 57/100
# 74/74 [==============================] - 43s 573ms/step - loss: 0.2695 - accuracy: 0.8906 - val_loss: 3.0827 - val_accuracy: 0.5416
# Epoch 58/100
# 74/74 [==============================] - 43s 573ms/step - loss: 0.2782 - accuracy: 0.8885 - val_loss: 1.9411 - val_accuracy: 0.5212
# Epoch 59/100
# 74/74 [==============================] - 43s 574ms/step - loss: 0.2383 - accuracy: 0.9046 - val_loss: 1.9633 - val_accuracy: 0.5314
# Epoch 60/100
# 74/74 [==============================] - 43s 572ms/step - loss: 0.2555 - accuracy: 0.8991 - val_loss: 1.5359 - val_accuracy: 0.5518
# Epoch 61/100
# 74/74 [==============================] - 43s 573ms/step - loss: 0.2453 - accuracy: 0.9033 - val_loss: 1.9588 - val_accuracy: 0.5501
# Epoch 62/100
# 74/74 [==============================] - 43s 574ms/step - loss: 0.2594 - accuracy: 0.8953 - val_loss: 1.6574 - val_accuracy: 0.5552
# Epoch 63/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.2136 - accuracy: 0.9169 - val_loss: 1.8871 - val_accuracy: 0.5433
# Epoch 64/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.2266 - accuracy: 0.9156 - val_loss: 1.6967 - val_accuracy: 0.5637
# Epoch 65/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.2049 - accuracy: 0.9254 - val_loss: 1.9843 - val_accuracy: 0.5433
# Epoch 66/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.2044 - accuracy: 0.9195 - val_loss: 1.6174 - val_accuracy: 0.5144
# Epoch 67/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.2139 - accuracy: 0.9190 - val_loss: 1.8999 - val_accuracy: 0.5416
# Epoch 68/100
# 74/74 [==============================] - 43s 574ms/step - loss: 0.1586 - accuracy: 0.9385 - val_loss: 1.9478 - val_accuracy: 0.5229
# Epoch 69/100
# 74/74 [==============================] - 43s 574ms/step - loss: 0.2100 - accuracy: 0.9190 - val_loss: 9.8546 - val_accuracy: 0.5263
# Epoch 70/100
# 74/74 [==============================] - 43s 573ms/step - loss: 0.1669 - accuracy: 0.9356 - val_loss: 2.3580 - val_accuracy: 0.5246
# Epoch 71/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.2176 - accuracy: 0.9178 - val_loss: 2.9591 - val_accuracy: 0.5280
# Epoch 72/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.2138 - accuracy: 0.9144 - val_loss: 2.8857 - val_accuracy: 0.5467
# Epoch 73/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.1961 - accuracy: 0.9228 - val_loss: 2.2142 - val_accuracy: 0.5518
# Epoch 74/100
# 74/74 [==============================] - 43s 574ms/step - loss: 0.1893 - accuracy: 0.9267 - val_loss: 3.7858 - val_accuracy: 0.5331
# Epoch 75/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.2407 - accuracy: 0.9055 - val_loss: 26.7646 - val_accuracy: 0.4499
# Epoch 76/100
# 74/74 [==============================] - 43s 573ms/step - loss: 0.1765 - accuracy: 0.9284 - val_loss: 1.9496 - val_accuracy: 0.5110
# Epoch 77/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.1562 - accuracy: 0.9368 - val_loss: 2.1133 - val_accuracy: 0.5093
# Epoch 78/100
# 74/74 [==============================] - 43s 574ms/step - loss: 0.1945 - accuracy: 0.9241 - val_loss: 1.7081 - val_accuracy: 0.5365
# Epoch 79/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.1921 - accuracy: 0.9178 - val_loss: 1.8213 - val_accuracy: 0.5297
# Epoch 80/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.1960 - accuracy: 0.9178 - val_loss: 1.8879 - val_accuracy: 0.5246
# Epoch 81/100
# 74/74 [==============================] - 43s 574ms/step - loss: 0.1857 - accuracy: 0.9334 - val_loss: 7.6058 - val_accuracy: 0.5144
# Epoch 82/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.1386 - accuracy: 0.9440 - val_loss: 3.4871 - val_accuracy: 0.5365
# Epoch 83/100
# 74/74 [==============================] - 43s 574ms/step - loss: 0.1722 - accuracy: 0.9330 - val_loss: 43.8080 - val_accuracy: 0.5093
# Epoch 84/100
# 74/74 [==============================] - 43s 574ms/step - loss: 0.1616 - accuracy: 0.9373 - val_loss: 2.0518 - val_accuracy: 0.5399
# Epoch 85/100
# 74/74 [==============================] - 43s 574ms/step - loss: 0.1663 - accuracy: 0.9398 - val_loss: 1.8769 - val_accuracy: 0.5433
# Epoch 86/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.1955 - accuracy: 0.9233 - val_loss: 5.4707 - val_accuracy: 0.5212
# Epoch 87/100
# 74/74 [==============================] - 43s 575ms/step - loss: 0.1843 - accuracy: 0.9334 - val_loss: 3.6942 - val_accuracy: 0.5399
# Epoch 88/100
# 74/74 [==============================] - 43s 573ms/step - loss: 0.1454 - accuracy: 0.9419 - val_loss: 1.9618 - val_accuracy: 0.5263
# Epoch 89/100
# 74/74 [==============================] - 43s 573ms/step - loss: 0.2162 - accuracy: 0.9237 - val_loss: 1.8615 - val_accuracy: 0.5874
# Epoch 90/100
# 74/74 [==============================] - 43s 573ms/step - loss: 0.2021 - accuracy: 0.9262 - val_loss: 3.0205 - val_accuracy: 0.4533
# Epoch 91/100
# 74/74 [==============================] - 43s 573ms/step - loss: 0.2624 - accuracy: 0.8991 - val_loss: 62.4443 - val_accuracy: 0.4805
# Epoch 92/100
# 74/74 [==============================] - 43s 574ms/step - loss: 0.1450 - accuracy: 0.9415 - val_loss: 211.7998 - val_accuracy: 0.4499
# Epoch 93/100
# 74/74 [==============================] - 43s 574ms/step - loss: 0.1342 - accuracy: 0.9453 - val_loss: 2.1949 - val_accuracy: 0.5467
# Epoch 94/100
# 74/74 [==============================] - 43s 574ms/step - loss: 0.1233 - accuracy: 0.9479 - val_loss: 1.8917 - val_accuracy: 0.5603
# Epoch 95/100
# 74/74 [==============================] - 43s 573ms/step - loss: 0.1235 - accuracy: 0.9508 - val_loss: 1.8677 - val_accuracy: 0.5637
# Epoch 96/100
# 74/74 [==============================] - 43s 573ms/step - loss: 0.1383 - accuracy: 0.9440 - val_loss: 2.3828 - val_accuracy: 0.4890
# Epoch 97/100
# 74/74 [==============================] - 43s 573ms/step - loss: 0.1255 - accuracy: 0.9483 - val_loss: 3.2617 - val_accuracy: 0.5042
# Epoch 98/100
# 74/74 [==============================] - 43s 573ms/step - loss: 0.1510 - accuracy: 0.9432 - val_loss: 2.3350 - val_accuracy: 0.5756
# Epoch 99/100
# 74/74 [==============================] - 43s 573ms/step - loss: 0.1349 - accuracy: 0.9462 - val_loss: 1.9193 - val_accuracy: 0.5739
# Epoch 100/100
# 74/74 [==============================] - 43s 573ms/step - loss: 0.1605 - accuracy: 0.9381 - val_loss: 1.9953 - val_accuracy: 0.5467

# %%
save_path = os.path.join(GOOGLE_DRIVE_PATH, 'Models')
model.save(os.path.join(save_path, 'resnet152'))

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs = range(1, len(acc) + 1)

# Plot training and validation accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, 'b', label='Training accuracy')
plt.plot(epochs, val_acc, 'g', label='Validation accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'g', label='Validation loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.show()
